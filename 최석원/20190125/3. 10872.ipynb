# %%
n = int(input())

result = 1

if n > 0 & n < 13:
    for i in range(1,n+1):
        result = result * i
print(result)
# Out:
# 25
# 15511210043330985984000000

# %%
n = int(input())

result = 1

if n > 0 & n < 13:
    for i in range(1,n+1):
        result = result * i
print(result)
# Out:
# 12
# 479001600

# %% [markdown]
# ### 문제
# 부동산 투자로 억대의 돈을 번 상도는 최근 N×N 크기의 땅을 구매했다. 상도는 손쉬운 땅 관리를 위해 땅을 1×1 크기의 칸으로 나누어 놓았다.
# 각각의 칸은 (r, c)로 나타내며, r은 가장 위에서부터 떨어진 칸의 개수, c는 가장 왼쪽으로부터 떨어진 칸의 개수이다. r과 c는 1부터 시작한다.
#
# 상도는 전자통신공학과 출신답게 땅의 양분을 조사하는 로봇 S2D2를 만들었다.
# S2D2는 1×1 크기의 칸에 들어있는 양분을 조사해 상도에게 전송하고, 모든 칸에 대해서 조사를 한다. 놀랍게도 양분은 모든 칸이 5만큼 들어있었다.
#
# 매일 매일 넓은 땅을 보면서 뿌듯한 하루를 보내고 있던 어느날 이런 생각이 들었다.
#
# 나무 재테크를 하자!
#
# 나무 재테크란 작은 묘목을 구매해 어느정도 키운 후 팔아서 수익을 얻는 재테크이다.
# 상도는 나무 재테크로 더 큰 돈을 벌기 위해 M개의 나무를 구매해 땅에 심었다. 같은 1×1 크기의 칸에 여러 개의 나무가 심어져 있을 수도 있다.
#
# 이 나무는 사계절을 보내며, 아래와 같은 과정을 반복한다.
#
# 봄에는 나무가 자신의 나이만큼 양분을 먹고, 나이가 1 증가한다. 각각의 나무는 나무가 있는 1×1 크기의 칸에 있는 양분만 먹을 수 있다.
# 하나의 칸에 여러 개의 나무가 있다면, 나이가 어린 나무부터 양분을 먹는다.
# 만약, 땅에 양분이 부족해 자신의 나이만큼 양분을 먹을 수 없는 나무는 양분을 먹지 못하고 즉시 죽는다.
#
# 여름에는 봄에 죽은 나무가 양분으로 변하게 된다.
# 각각의 죽은 나무마다 나이를 2로 나눈 값이 나무가 있던 칸에 양분으로 추가된다. 소수점 아래는 버린다.
#
# 가을에는 나무가 번식한다. 번식하는 나무는 나이가 5의 배수이어야 하며, 인접한 8개의 칸에 나이가 1인 나무가 생긴다.
# 어떤 칸 (r, c)와 인접한 칸은 (r-1, c-1), (r-1, c), (r-1, c+1), (r, c-1), (r, c+1), (r+1, c-1), (r+1, c), (r+1, c+1) 이다.
# 상도의 땅을 벗어나는 칸에는 나무가 생기지 않는다.
#
# 겨울에는 S2D2가 땅을 돌아다니면서 땅에 양분을 추가한다. 각 칸에 추가되는 양분의 양은 A[r][c]이고, 입력으로 주어진다.
#
# K년이 지난 후 상도의 땅에 살아있는 나무의 개수를 구하는 프로그램을 작성하시오.
#
# ### 입력
# 첫째 줄에 N, M, K가 주어진다.
#
# 둘째 줄부터 N개의 줄에 A배열의 값이 주어진다. r번째 줄의 c번째 값은 A[r][c]이다.
#
# 다음 M개의 줄에는 상도가 심은 나무의 정보를 나타내는 세 정수 x, y, z가 주어진다.
# 처음 두 개의 정수는 나무의 위치 (x, y)를 의미하고, 마지막 정수는 그 나무의 나이를 의미한다.
#
# ### 출력
# 첫째 줄에 K년이 지난 후 살아남은 나무의 수를 출력한다.

# %% [markdown]
# ### ------------------------------------------------------------------------------

# %% [markdown]
# 각 계절마다 함수를 만들어서 K번째 겨울이 지날때까지 진행.

# %%
# import sys
# input = sys.stdin.readline
from collections import deque
dx = 1, 1, 1, 0, 0, -1, -1, -1
dy = -1, 0, 1, -1, 1, -1, 0, 1

N, M, K = map(int, input().split())   # 지도크기 N x N / 초기 나무 정보 M개 / K년이 지날때까지 시뮬레이션.

# 매 해 겨울마다 추가되는 양분정보. 좌표가 1,1부터 N, N까지.(주의!) 
A = [list(map(int, input().split())) for _ in range(N)]
# 얘를 현재 양분정보로 이용.. 
C = [[5]*N for _ in range(N)]

# 초기 나무정보. (x, y, 나이). 처음에는 겹치는 나무 없음. 좌표 1, 1부터 N, N까지!!
trees = deque(tuple(map(int, input().split())) for _ in range(M))
# 봄, 여름에 사용될 죽은 나무정보. 얘도, 좌표+나이 함께 저장.
dead = deque()
# 나이가 5의 배수가 된 애들 따로 저장.. 얘는 좌표만 필요.
prop = deque()
print(f'처음 trees= {trees}')
# 봄에는 나무가 자란다. 그 칸의 양분을 자기 나이만큼 먹어고 나이가 1 증가함. 양분이 부족해서 못먹는애는 죽음.
def spring():
    for _ in range(len(trees)):
        x, y, old = trees.popleft()
        print(f'현재 x, y, old, 땅의양분 = {x}, {y}, {old}, {C[y-1][x-1]}')
        if C[x-1][y-1] >= old:
            C[x-1][y-1] -= old
            trees.append((x,y,old+1))
            if (old+1) % 5 == 0:
                prop.append((x,y))
        else:
            dead.append((x,y,old))
# 여름에는 죽은 나무가 자기나이//2 만큼 양분이됨. 
def summer():
    while dead:
        x, y, old = dead.pop()
        C[x-1][y-1] += old//2

# 가을에는 나이가 5의 배수인 나무 주위 8칸에 1살짜리 새로운 나무가 생긴다. (지도 범위 내에서)
def autumn():
    while prop:
        x, y = prop.pop()
        for d in range(8):
            nx, ny = x + dx[d], y + dy[d]
            if nx>=1 and nx<=N and ny>=1 and ny<=N:
                trees.appendleft((nx, ny, 1))
    

# 겨울에는 각 지역에 매 년마다 일정한 양의 양분이 추가됨.
def winter():
    for j in range(N):
        for i in range(N):
            C[j][i] += A[j][i]

# K년동안 반복.
for _ in range(K):
    spring()
    summer()
    autumn()
    winter()
print(trees)
print(len(trees))
# Out:
# 5 2 5
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 1 3
# 3 2 3
# 처음 trees= deque([(2, 1, 3), (3, 2, 3)])
# 현재 x, y, old, 땅의양분 = 2, 1, 3, 5
# 현재 x, y, old, 땅의양분 = 3, 2, 3, 5
# 현재 x, y, old, 땅의양분 = 2, 1, 4, 8
# 현재 x, y, old, 땅의양분 = 3, 2, 4, 7
# 현재 x, y, old, 땅의양분 = 1, 2, 1, 2
# 현재 x, y, old, 땅의양분 = 1, 1, 1, 9
# 현재 x, y, old, 땅의양분 = 2, 2, 1, 11
# 현재 x, y, old, 땅의양분 = 3, 2, 1, 9
# 현재 x, y, old, 땅의양분 = 3, 1, 1, 9
# 현재 x, y, old, 땅의양분 = 2, 3, 1, 3
# 현재 x, y, old, 땅의양분 = 2, 2, 1, 10
# 현재 x, y, old, 땅의양분 = 2, 1, 1, 10
# 현재 x, y, old, 땅의양분 = 3, 3, 1, 9
# 현재 x, y, old, 땅의양분 = 3, 1, 1, 9
# 현재 x, y, old, 땅의양분 = 4, 3, 1, 11
# 현재 x, y, old, 땅의양분 = 4, 2, 1, 11
# 현재 x, y, old, 땅의양분 = 4, 1, 1, 11
# 현재 x, y, old, 땅의양분 = 2, 1, 5, 10
# 현재 x, y, old, 땅의양분 = 3, 2, 5, 8
# 현재 x, y, old, 땅의양분 = 1, 2, 2, 5
# 현재 x, y, old, 땅의양분 = 1, 1, 2, 10
# 현재 x, y, old, 땅의양분 = 2, 2, 2, 12
# 현재 x, y, old, 땅의양분 = 3, 2, 2, 10
# 현재 x, y, old, 땅의양분 = 3, 1, 2, 11
# 현재 x, y, old, 땅의양분 = 2, 3, 2, 6
# ...

# %% [markdown]
# 5 2 5
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 3 2 3 2
# 2 1 3
# 3 2 3
#
# ---
# 13

# %% [markdown]
# 1316ms. 좌표 주의! x가 위에서부터.  함수호출을 줄이면 좀 더 빠를수도..

# %%
# import sys
# input = sys.stdin.readline
from collections import deque
dx = 1, 1, 1, 0, 0, -1, -1, -1
dy = -1, 0, 1, -1, 1, -1, 0, 1
N, M, K = map(int, input().split())
A = [list(map(int, input().split())) for _ in range(N)]
C = [[5]*N for _ in range(N)]
trees = deque(tuple(map(int, input().split())) for _ in range(M))
dead = deque()
prop = deque()

for _ in range(K):
    for _ in range(len(trees)):
        x, y, old = trees.popleft()
        if C[x-1][y-1] >= old:
            C[x-1][y-1] -= old
            trees.append((x,y,old+1))
            if (old+1) % 5 == 0:
                prop.append((x,y))
        else:
            dead.append((x,y,old))
    if not dead:
        break
    while dead:
        x, y, old = dead.pop()
        C[x-1][y-1] += old//2
    while prop:
        x, y = prop.pop()
        for d in range(8):
            nx, ny = x + dx[d], y + dy[d]
            if nx>=1 and nx<=N and ny>=1 and ny<=N:
                trees.appendleft((nx, ny, 1))
    for j in range(N):
        for i in range(N):
            C[j][i] += A[j][i]
print(len(trees))

# %% [markdown]
# 별 차이 없네.. 어디서 오래걸릴까..
